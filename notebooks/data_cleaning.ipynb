# %%
rows_after, cols_after = df.shape
rows_after, cols_after
# Out:
# (825, 11)

# %%
df.to_csv("../data/cleaned_dataset.csv", index=False)
print("Saved cleaned dataset to ../data/cleaned_dataset.csv")
# Out:
# Saved cleaned dataset to ../data/cleaned_dataset.csv

# %%
print("Final Shape:", df.shape)
display(df.head())
display(df.describe(include="all"))
print("Final missing values:\n", df.isnull().sum())
# Out:
# Final Shape: (825, 11)
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S
#         PassengerId    Survived      Pclass                 Name   Sex  \
# count    825.000000  825.000000  825.000000                  825   825
# unique          NaN         NaN         NaN                  825     2
# top             NaN         NaN         NaN  Dooley, Mr. Patrick  male
# freq            NaN         NaN         NaN                    1   531
# mean     447.369697    0.380606    2.341818                  NaN   NaN
# std      257.088865    0.485830    0.824096                  NaN   NaN
# min        1.000000    0.000000    1.000000                  NaN   NaN
# 25%      226.000000    0.000000    2.000000                  NaN   NaN
# 50%      445.000000    0.000000    3.000000                  NaN   NaN
# 75%      671.000000    1.000000    3.000000                  NaN   NaN
# max      891.000000    1.000000    3.000000                  NaN   NaN
#
#                Age       SibSp       Parch Ticket        Fare Embarked
# count   825.000000  825.000000  825.000000    825  825.000000      825
# unique         NaN         NaN         NaN    647         NaN        3
# top            NaN         NaN         NaN   1601         NaN        S
# freq           NaN         NaN         NaN      7         NaN      600
# mean     28.515152    0.507879    0.357576    NaN   31.483615      NaN
# std      10.177256    1.090670    0.798599    NaN   49.956429      NaN
# min       3.000000    0.000000    0.000000    NaN    0.000000      NaN
# 25%      22.000000    0.000000    0.000000    NaN    7.895800      NaN
# 50%      28.000000    0.000000    0.000000    NaN   13.416700      NaN
# 75%      34.000000    1.000000    0.000000    NaN   30.070800      NaN
# max      54.000000    8.000000    6.000000    NaN  512.329200      NaN
# Final missing values:
#  PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
print("Age stats AFTER:")
print(df['Age'].describe())
# Out:
# Age stats AFTER:
# count    825.000000
# mean      28.515152
# std       10.177256
# min        3.000000
# 25%       22.000000
# 50%       28.000000
# 75%       34.000000
# max       54.000000
# Name: Age, dtype: float64

# %%
Q1 = df['Age'].quantile(0.25)
Q3 = df['Age'].quantile(0.75)
IQR = Q3 - Q1
mask = ~((df['Age'] < (Q1 - 1.5 * IQR)) | (df['Age'] > (Q3 + 1.5 * IQR)))
df = df[mask].copy()
print("Shape after removing Age outliers:", df.shape)
# Out:
# Shape after removing Age outliers: (825, 11)

# %%
print("Age stats BEFORE:")
print(df['Age'].describe())
# Out:
# Age stats BEFORE:
# count    891.000000
# mean      29.361582
# std       13.019697
# min        0.420000
# 25%       22.000000
# 50%       28.000000
# 75%       35.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
print("Missing values now:\n", df.isnull().sum())
# Out:
# Missing values now:
#  PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df['Age'] = df['Age'].fillna(df['Age'].median())
df['Embarked'] = df['Embarked'].fillna(df['Embarked'].mode()[0])

df = df.drop(columns=['Cabin'], errors='ignore')

df = df.drop_duplicates()

df['Name'] = df['Name'].str.title()
df['Sex'] = df['Sex'].str.lower()

print("Shape after basic cleaning:", df.shape)
df.head()
# Out:
# Shape after basic cleaning: (891, 11)
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
rows_before, cols_before = df.shape
rows_before, cols_before
# Out:
# (891, 12)

# %%
df.info()
print("\n--- Describe ---\n")
display(df.describe(include="all"))
print("\n--- Missing values ---\n")
print(df.isnull().sum())
print("\n--- Duplicates ---\n")
print("Duplicate rows:", df.duplicated().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
#
# --- Describe ---
#         PassengerId    Survived      Pclass                 Name   Sex  \
# count    891.000000  891.000000  891.000000                  891   891
# unique          NaN         NaN         NaN                  891     2
# top             NaN         NaN         NaN  Dooley, Mr. Patrick  male
# freq            NaN         NaN         NaN                    1   577
# mean     446.000000    0.383838    2.308642                  NaN   NaN
# std      257.353842    0.486592    0.836071                  NaN   NaN
# min        1.000000    0.000000    1.000000                  NaN   NaN
# 25%      223.500000    0.000000    2.000000                  NaN   NaN
# 50%      446.000000    0.000000    3.000000                  NaN   NaN
# 75%      668.500000    1.000000    3.000000                  NaN   NaN
# max      891.000000    1.000000    3.000000                  NaN   NaN
#
#                Age       SibSp       Parch  Ticket        Fare Cabin Embarked
# count   714.000000  891.000000  891.000000     891  891.000000   204      889
# unique         NaN         NaN         NaN     681         NaN   147        3
# top            NaN         NaN         NaN  347082         NaN    G6        S
# freq           NaN         NaN         NaN       7         NaN     4      644
# mean     29.699118    0.523008    0.381594     NaN   32.204208   NaN      NaN
# std      14.526497    1.102743    0.806057     NaN   49.693429   NaN      NaN
# min       0.420000    0.000000    0.000000     NaN    0.000000   NaN      NaN
# 25%      20.125000    0.000000    0.000000     NaN    7.910400   NaN      NaN
# 50%      28.000000    0.000000    0.000000     NaN   14.454200   NaN      NaN
# 75%      38.000000    1.000000    0.000000     NaN   31.000000   NaN      NaN
# max      80.000000    8.000000    6.000000     NaN  512.329200   NaN      NaN
# --- Missing values ---
#
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
#
# --- Duplicates ---
#
# Duplicate rows: 0

# %%
df = pd.read_csv("../data/raw_dataset.csv")
print("Initial Shape:", df.shape)
df.head()
# Out:
# Initial Shape: (891, 12)
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
import pandas as pd
import numpy as np
